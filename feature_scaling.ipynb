# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')
df.head(6)
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0            19000          0
# 1  15810944    Male  35.0            20000          0
# 2  15668575  Female   NaN            43000          0
# 3  15603246  Female  27.0            57000          0
# 4  15804002    Male  19.0            76000          0
# 5  15728773    Male  27.0            58000          0

# %%
df = df.iloc[:,2:]

# %%
df.head(6)
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0            19000          0
# 1  35.0            20000          0
# 2   NaN            43000          0
# 3  27.0            57000          0
# 4  19.0            76000          0
# 5  27.0            58000          0

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean().round())

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Age','EstimatedSalary']], df['Purchased'], test_size=.3)

# %%
X_train.shape, X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
sc.mean_
# Out:
# array([3.79642857e+01, 7.11107143e+04])

# %%
X_train_scaled = sc.transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax2.scatter(X_train_sc_DF['Age'], X_train_sc_DF['EstimatedSalary'], color='red')
plt.show()

# %%
X_train_sc_DF = pd.DataFrame(X_train_scaled, columns=['Age', 'EstimatedSalary'])

# %%
X_train_sc_DF
# Out:
#           Age  EstimatedSalary
# 0    0.111407        -0.804236
# 1   -0.272518        -0.347654
# 2    1.743089         1.082968
# 3   -1.424294        -0.621603
# 4   -1.232332         0.565509
# ..        ...              ...
# 275  1.071220        -0.986869
# 276 -0.464481        -1.139063
# 277  0.015426        -0.530287
# 278 -1.136350        -1.017308
# 279 -1.520276        -0.165022
#
# [280 rows x 2 columns]
