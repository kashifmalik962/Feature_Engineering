# %% [markdown]
# Our Goal is Find the value of b

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
plt.figure(figsize=(5,3))
plt.scatter(X,y)

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [82.59761169]
# -1.3833806520909135

# %%
m = 82.59

# %%
class GDregressor:

  def __init__(self, learning_rate, epochs):

    self.m = 82.59
    self.b = -120
    self.lrr = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
    # calculate b using GD
    for i in range(self.epochs):
      loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
      self.b = self.b - (self.lrr * loss_slope)
      print(loss_slope, self.b)

    print(self.b)

# %%
gd = GDregressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -23723.5396912271 -96.2764603087729
# -18978.831752981685 -77.29762855579122
# -15183.065402385344 -62.114563153405875
# -12146.452321908273 -49.968110831497604
# -9717.16185752662 -40.250948973970985
# -7773.729486021297 -32.47721948794969
# -6218.983588817037 -26.25823589913265
# -4975.186871053629 -21.28304902807902
# -3980.1494968429042 -17.302899531236115
# -3184.119597474323 -14.118779933761791
# -2547.2956779794586 -11.571484255782334
# -2037.836542383567 -9.533647713398768
# -1630.2692339068537 -7.903378479491914
# -1304.2153871254832 -6.599163092366431
# -1043.3723097003863 -5.555790782666045
# -834.6978477603094 -4.721092934905736
# -667.7582782082475 -4.053334656697488
# -534.2066225665976 -3.5191280341308904
# -427.36529805327814 -3.0917627360776123
# -341.89223844262267 -2.7498704976349897
# -273.51379075409807 -2.4763567068808916
# -218.8110326032787 -2.2575456742776128
# -175.04882608262264 -2.08249684819499
# -140.03906086609825 -1.942457787328892
# ...

# %%
lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [82.59761169]
# -1.3833806520909135

# %%
plt.figure(figsize=(4,3))
plt.scatter(X,y)
plt.plot(X,lr.predict(X), color='red')

# %%
y_pred = ((82.59 * X) + 120)

# %%
plt.figure(figsize=(6,4))
plt.scatter(X,y)
plt.plot(X,lr.predict(X), color='red', label='OLS')
plt.plot(X,y_pred, color='green', label='GD')
plt.legend()
plt.show()

# %%
m = 82.590
b = 120

loss_slope = -2 * np.sum(y - 82.59 * X.ravel() - b)
loss_slope
# Out:
# 24276.4603087729

# %%
lrr = 0.001

# %%
step_size = loss_slope*lrr
step_size
# Out:
# 24.2764603087729

# %%
# calculate new Intercept
b = b - step_size
b
# Out:
# 95.7235396912271

# %%
y_pred1 = ((82.59 * X) - b)
plt.figure(figsize=(6,4))
plt.scatter(X,y)
plt.plot(X,lr.predict(X), color='red', label='OLS')
plt.plot(X,y_pred1, color='black', label='b = {}'.format(b))
plt.plot(X,y_pred, color='green', label='b = 120')
plt.legend()
plt.show()

# %%
# iteration 3
loss_slope = -2 * np.sum(y - m * X.ravel() - b)
loss_slope
# Out:
# 19421.168247018315

# %%
step_size = loss_slope*lrr
step_size
# Out:
# 19.421168247018315

# %%
b = b - step_size
b
# Out:
# 76.30237144420879

# %%
y_pred2 = ((m * X) + b)

plt.figure(figsize=(6,4))
plt.scatter(X,y)
plt.plot(X,lr.predict(X), color='red', label='OLS')
plt.plot(X,y_pred1, color='black', label='b = {}'.format(b))
plt.plot(X,y_pred2, color='orange', label='b = {}'.format(b))
plt.plot(X,y_pred, color='green', label='b = 120')
plt.legend()
plt.show()

# %%
# iteration 4
loss_slope = -2 * np.sum(y - m * X.ravel() - b)
loss_slope
# Out:
# 15536.934597614654

# %%
step_size = loss_slope*lrr
step_size
# Out:
# 15.536934597614655

# %%
b = b - step_size
b
# Out:
# 60.765436846594135

# %%
y_pred3 = ((m * X) + b)

plt.figure(figsize=(6,4))
plt.scatter(X,y)
plt.plot(X,lr.predict(X), color='red', label='OLS')
plt.plot(X,y_pred1, color='black', label='b = {}'.format(b))
plt.plot(X,y_pred2, color='orange', label='b = {}'.format(b))
plt.plot(X,y_pred3, color='yellow', label='b = {}'.format(b))
plt.plot(X,y_pred, color='green', label='b = 120')
plt.legend()
plt.show()

# %%
b = -200
plt.figure(figsize=(10,5))
for i in range(50):
  loss_slope = -2 * np.sum(y - m * X.ravel() - b)
  step_size = loss_slope*lrr
  b = b - step_size

  y_pred4 = ((m * X) + b)
  plt.plot(X,lr.predict(X), color='red')
  plt.plot(X,y_pred4, color='green')  
plt.scatter(X,y)
plt.legend()
plt.show()
print(b)
print(m)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# -1.3851363103830197
# 82.59

# %% [markdown]
# Find the value of (m,b) using Gradient Descent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
lrr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=13)

# %%
lrr.fit(X_train,y_train)
print(lrr.coef_)
print(lrr.intercept_)
# Out:
# [28.14641458]
# -2.5171658346421597

# %%
y_pred = lrr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred, y_test)
# Out:
# 0.6362112123105211

# %%
class GDregressor:
  
  def __init__(self, learning_rate, epochs):
    self.b = 100
    self.m = -120
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
    
    for i in range(self.epochs):
      # calculate value of b using GD
      loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
      self.b = self.b - (loss_slope_b * self.lr)

      loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
      self.m = self.m - (loss_slope_m * self.lr)

    print(self.m, self.b)

  def predict(self, X):

    return (self.m * X) + self.b

# %%
gd = GDregressor(0.001, 100)

# %%
gd.fit(X_train,y_train)
# Out:
# 28.146153346832318 -2.517260743523889

# %%
gd.predict(X_test)
# Out:
# array([[ 34.92604339],
#        [ 50.75615199],
#        [ 20.86953732],
#        [-24.15115474],
#        [ 10.19951863],
#        [-14.61720993],
#        [ 30.99651245],
#        [ 19.0401891 ],
#        [ -6.60440118],
#        [ -4.81543796],
#        [-38.02661514],
#        [ 12.90453202],
#        [  3.33151142],
#        [ 55.28630401],
#        [ -2.58450262],
#        [ 58.00774801],
#        [ 12.46600309],
#        [-17.24232096],
#        [ 39.10205477],
#        [ -3.27077971],
#        [ 24.30125575],
#        [  4.17752245],
#        [  7.29872695],
#        [ 17.49394486],
#        [-24.72426683]])

# %%
y_pred = gd.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7044064059860375

# %%
pred = gd.predict(X)
